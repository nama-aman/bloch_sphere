# %% [markdown]
# # Using package block_sphere

# %% [markdown]
# Few Gates:
# - h_gate()
# - x_gate()
# - y_gate()
# - z_gate()
# - sqrt_y_gate()
# - s_gate()
# - custom_gate(x,y,z,angle, label) here A=(x,y,z) defines OA is axis of rotation

# %%
# !pip install pycairo
# !pip install pylatex
# !pip install drawSvg
# !pip install latextools
# !pip install pdflatex
# !pip install hyperbolic
# !pip install imageio_ffmpeg

from IPython.display import clear_output
clear_output()
import bloch_sphere

# %%
from bloch_sphere.animate_bloch import do_or_save_animation, AnimState,draw_bloch_sphere
from bloch_sphere.animate_bloch_compare import render_animation

@do_or_save_animation('my_animation', save=False, fps=20, preview=True)
# Or
# @do_or_save_animation('my_animation', save='gif', fps=20, preview=False)
# @do_or_save_animation('anim_zgate', save='mp4', fps=20, preview=True)
def animate(state: AnimState):
    state.y_gate()
    # state.y_gate()
    # state.s_gate()
    # state.s_gate()
    ...
    state.wait()

# %%
@do_or_save_animation('my_animation', save=False, fps=20, preview=True)
def animate(state:AnimState):
        state.custom_gate(1,0,0,r_pi=1,label="RX Gate")
        state.wait(2)
